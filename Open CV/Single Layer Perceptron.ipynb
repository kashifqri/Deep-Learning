# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from mlxtend.plotting import plot_decision_regions

# %%
datasets = pd.read_csv("C://Users//basit//Downloads//Placement (1).csv")

# %%
datasets
# Out:
#     CGPA   IQ  Placement
# 0    6.8  123          1
# 1    5.9  106          0
# 2    5.3  121          0
# 3    7.4  132          1
# 4    5.8  142          0
# ..   ...  ...        ...
# 95   4.3  200          0
# 96   4.4   42          0
# 97   6.7  182          1
# 98   6.3  103          1
# 99   6.2  113          1
#
# [100 rows x 3 columns]

# %%
sns.scatterplot(x="CGPA",y="IQ",hue="Placement",data=datasets)
plt.show()

# %%
x=datasets.iloc[:,:-1]
y= datasets["Placement"]

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,train_size=0.2,random_state=10)

# %%
from sklearn.linear_model import Perceptron

# %%
pr =Perceptron()
pr.fit(x_train,y_train)
# Out:
# Perceptron()

# %%
pr.score(x_train,y_train)*100 , pr.score(x_test,y_test)*100
# Out:
# (65.0, 46.25)

# %%
plot_decision_regions(x.to_numpy(),y.to_numpy(),clf=pr)
plt.show()
# Out:
# C:\Users\basit\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but Perceptron was fitted with feature names
#   warnings.warn(
